# %% [markdown]
# # Direct translation to RTL
#
# The primitive example below demonstrates how to directly synthesize from a cyHDL notation to yosys RTL and display using the .dot backend.

# %%
from cyhdl import *

# %%
@block
def unitx(clk : ClkSignal, a : Signal, b : Signal.Output):
    @always(clk.posedge)
    def worker():
        if a < 20:
            b.next = concat(a[3:], a[4:])
            if a > 6:
                b.next = 0
        elif a < 4:
            b.next = 44
        
    return instances()

# %%
from myirl.targets import pyosys

def test():
    
    clk = ClkSignal()
    a, b = [ Signal(intbv()[7:]) for _ in range(2) ]
    u = unitx(clk, a, b)

    r = pyosys.RTLIL("top1")
    d = u.elab(r)
    d[0].run("opt")
    d[0].display_rtl(fmt="dot")
    return d[0]
design = test()
# Out:
#  Adding module with name `unitx`
#  FINALIZE implementation `unitx` of `unitx`

# %%
from yosys import display
display.display_dot(design.name)
# Out:
#         <div class="svg_container_1713902030">
#             <style>
#                 .svg_container_1713902030 {
#                     overflow:hidden
#                 }
#                 .svg_container_1713902030 SVG {
#                     height:auto
#                 }
#             </style>
#             <script src="https://section5.ch/svg-pan-zoom.min.js"></script>
#             <script type="text/javascript">
#                 attempts = 5;
#                 var existCondition = setInterval(function() {
#                   console.log(attempts);
#                   svg_el = document.querySelector(".svg_container_1713902030 svg");
#                   if (svg_el != null) {
#                       console.log("Exists!");
#                       clearInterval(existCondition);
#                       svgPanZoom(svg_el, {controlIconsEnabled: true, zoomScaleSensitivity: 0.4, minZoom: 0.2});
#                   }
#                   if (--attempts == 0) {
#                       console.warn("SVG element not found, zoom wont work");
#                       clearInterval(existCondition);
#                   }
#                 }, 100); // check every 100ms
#             </script>
#             <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="1176pt" height="401pt" viewBox="0.00 0.00 1175.59 401.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 397)">
# <title>unitx</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-397 1171.59,-397 1171.59,4 -4,4"/>
# <text text-anchor="middle" x="583.79" y="-7.8" font-family="Times,serif" font-size="14.00">unitx</text>
# <!-- n8 -->
# <g id="node1" class="node">
# <title>n8</title>
# <polygon fill="none" stroke="black" points="86.79,-177.54 86.79,-192.46 70.98,-203 48.61,-203 32.79,-192.46 32.79,-177.54 48.61,-167 70.98,-167 86.79,-177.54"/>
# <text text-anchor="middle" x="59.79" y="-181.3" font-family="Times,serif" font-size="14.00">a</text>
# </g>
# <!-- x0 -->
# <g id="node6" class="node">
# <title>x0</title>
# <path fill="none" stroke="black" d="M247.59,-150C247.59,-150 298.59,-150 298.59,-150 304.59,-150 310.59,-156 310.59,-162 310.59,-162 310.59,-184 310.59,-184 310.59,-190 304.59,-196 298.59,-196 298.59,-196 247.59,-196 247.59,-196 241.59,-196 235.59,-190 235.59,-184 235.59,-184 235.59,-162 235.59,-162 235.59,-156 241.59,-150 247.59,-150"/>
# <text text-anchor="middle" x="273.09" y="-180.8" font-family="Times,serif" font-size="14.00">2:0 - 6:4</text>
# <polyline fill="none" stroke="black" points="235.59,-173 310.59,-173 "/>
# <text text-anchor="middle" x="273.09" y="-157.8" font-family="Times,serif" font-size="14.00">3:0 - 3:0</text>
# </g>
# <!-- n8&#45;&gt;x0 -->
# <g id="edge18" class="edge">
# <title>n8:e-&gt;x0:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M87.79,-185C150.21,-185 166.53,-163.46 224.08,-161.19"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="224.16,-164.69 234.09,-161 224.02,-157.69 224.16,-164.69"/>
# </g>
# <!-- n8&#45;&gt;x0 -->
# <g id="edge19" class="edge">
# <title>n8:e-&gt;x0:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M87.79,-185C149.26,-185 167.15,-185 223.84,-185"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="224.09,-188.5 234.09,-185 224.09,-181.5 224.09,-188.5"/>
# </g>
# <!-- c24 -->
# <g id="node15" class="node">
# <title>c24</title>
# <polygon fill="none" stroke="black" points="155.59,-280 155.59,-326 390.59,-326 390.59,-280 155.59,-280"/>
# <text text-anchor="middle" x="169.09" y="-310.8" font-family="Times,serif" font-size="14.00">A</text>
# <polyline fill="none" stroke="black" points="155.59,-303 182.59,-303 "/>
# <text text-anchor="middle" x="169.09" y="-287.8" font-family="Times,serif" font-size="14.00">B</text>
# <polyline fill="none" stroke="black" points="182.59,-280 182.59,-326 "/>
# <text text-anchor="middle" x="273.59" y="-306.8" font-family="Times,serif" font-size="14.00">$worker:10::4da5/gt:_u</text>
# <text text-anchor="middle" x="273.59" y="-291.8" font-family="Times,serif" font-size="14.00">$gt</text>
# <polyline fill="none" stroke="black" points="364.59,-280 364.59,-326 "/>
# <text text-anchor="middle" x="377.59" y="-299.3" font-family="Times,serif" font-size="14.00">Y</text>
# </g>
# <!-- n8&#45;&gt;c24 -->
# <g id="edge15" class="edge">
# <title>n8:e-&gt;c24:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M87.79,-185C139.89,-185 105.22,-277 145.46,-289.58"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="145.2,-293.08 155.59,-291 146.17,-286.15 145.2,-293.08"/>
# </g>
# <!-- c25 -->
# <g id="node17" class="node">
# <title>c25</title>
# <polygon fill="none" stroke="black" points="159.59,-215 159.59,-261 386.59,-261 386.59,-215 159.59,-215"/>
# <text text-anchor="middle" x="173.09" y="-245.8" font-family="Times,serif" font-size="14.00">A</text>
# <polyline fill="none" stroke="black" points="159.59,-238 186.59,-238 "/>
# <text text-anchor="middle" x="173.09" y="-222.8" font-family="Times,serif" font-size="14.00">B</text>
# <polyline fill="none" stroke="black" points="186.59,-215 186.59,-261 "/>
# <text text-anchor="middle" x="273.59" y="-241.8" font-family="Times,serif" font-size="14.00">$worker:8::4021/gt:_u</text>
# <text text-anchor="middle" x="273.59" y="-226.8" font-family="Times,serif" font-size="14.00">$gt</text>
# <polyline fill="none" stroke="black" points="360.59,-215 360.59,-261 "/>
# <text text-anchor="middle" x="373.59" y="-234.3" font-family="Times,serif" font-size="14.00">Y</text>
# </g>
# <!-- n8&#45;&gt;c25 -->
# <g id="edge16" class="edge">
# <title>n8:e-&gt;c25:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M87.79,-185C120.15,-185 121.93,-217.81 147.83,-224.73"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="147.73,-228.24 158.09,-226 148.6,-221.3 147.73,-228.24"/>
# </g>
# <!-- c26 -->
# <g id="node19" class="node">
# <title>c26</title>
# <polygon fill="none" stroke="black" points="159.59,-30 159.59,-76 386.59,-76 386.59,-30 159.59,-30"/>
# <text text-anchor="middle" x="173.09" y="-60.8" font-family="Times,serif" font-size="14.00">A</text>
# <polyline fill="none" stroke="black" points="159.59,-53 186.59,-53 "/>
# <text text-anchor="middle" x="173.09" y="-37.8" font-family="Times,serif" font-size="14.00">B</text>
# <polyline fill="none" stroke="black" points="186.59,-30 186.59,-76 "/>
# <text text-anchor="middle" x="273.59" y="-56.8" font-family="Times,serif" font-size="14.00">$worker:8::9558/gt:_u</text>
# <text text-anchor="middle" x="273.59" y="-41.8" font-family="Times,serif" font-size="14.00">$gt</text>
# <polyline fill="none" stroke="black" points="360.59,-30 360.59,-76 "/>
# <text text-anchor="middle" x="373.59" y="-49.3" font-family="Times,serif" font-size="14.00">Y</text>
# </g>
# <!-- n8&#45;&gt;c26 -->
# <g id="edge17" class="edge">
# <title>n8:e-&gt;c26:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M87.79,-185C145.86,-185 102.31,-79.09 148.08,-66.27"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="148.61,-69.73 158.09,-65 147.73,-62.78 148.61,-69.73"/>
# </g>
# <!-- n9 -->
# <g id="node2" class="node">
# <title>n9</title>
# <polygon fill="none" stroke="black" points="1167.59,-272.54 1167.59,-287.46 1151.77,-298 1129.41,-298 1113.59,-287.46 1113.59,-272.54 1129.41,-262 1151.77,-262 1167.59,-272.54"/>
# <text text-anchor="middle" x="1140.59" y="-276.3" font-family="Times,serif" font-size="14.00">b</text>
# </g>
# <!-- n10 -->
# <g id="node3" class="node">
# <title>n10</title>
# <polygon fill="none" stroke="black" points="859.09,-343.54 859.09,-358.46 843.27,-369 820.91,-369 805.09,-358.46 805.09,-343.54 820.91,-333 843.27,-333 859.09,-343.54"/>
# <text text-anchor="middle" x="832.09" y="-347.3" font-family="Times,serif" font-size="14.00">clk</text>
# </g>
# <!-- c22 -->
# <g id="node11" class="node">
# <title>c22</title>
# <polygon fill="none" stroke="black" points="949.59,-245.5 949.59,-314.5 1077.59,-314.5 1077.59,-245.5 949.59,-245.5"/>
# <text text-anchor="middle" x="973.09" y="-299.3" font-family="Times,serif" font-size="14.00">CLK</text>
# <polyline fill="none" stroke="black" points="949.59,-291.5 996.59,-
