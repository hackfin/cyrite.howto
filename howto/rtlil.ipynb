# %% [markdown]
# # Yosys direct synthesis
#
# The pyosys.RTLIL target provides direct output of synthesizable designs from the intermediate IRL description.
#
# ## Examples

# %%
from cyhdl import *

@block
def unit(clk : ClkSignal,
         en : Signal.Type(bool),
         a : Signal,
         b  :Signal,
         q : Signal.Output):
    
    @always(clk.posedge)
    def worker():
        if en:
            q.next = a | b
        else:
            q.next = a ^ b
    
    return instances()

# %% [markdown]
# ### Deriving from the RTLIL target
#
# It is good practise to derive from the RTLIL class in a central location. This class can then easily be adapted with a .finalize() method to run custom commands on the synthesized elements.

# %%
from myirl.targets.pyosys import RTLIL

class RTL(RTLIL):
    def __init__(self):
        super().__init__("custom")
    def finalize(self, top, objs):
        tname = top.name
        design = self._design
        # design.run("hierarchy -check ; opt")
        self.log("FINALIZE implementation `%s` of `%s`" % (tname, top.obj.name), annotation='info')
        return [objs]

# %% [markdown]
# ### Synthesis
#
# We synthesize an implementation of this unit by creating the corresponding pin signals. Note that there can be several implementations, if this unit is instanced in various places with differing signal configurations (sizes).

# %%
rtl = RTL()
N = 12

clk = ClkSignal()
u, v, w, = [ Signal(intbv()[N:]) for _ in range(3) ]
en = Signal(bool())

u = unit(clk, en, u, v, w)
objs = u.elab(rtl)
design = objs[0]
# Out:
#  Adding module with name `unit`
#  FINALIZE implementation `unit` of `unit`

# %% [markdown]
# If the design is a flat structure with no hierarchy, we can simply display it using the `inline` specification.
#
# Care must be taken on big designs, as they may create large files that the browser is unable to display.

# %%
design.display_rtl(inline = True)
# Out:
#         <div class="svg_container_1715150788">
#             <style>
#                 .svg_container_1715150788 {
#                     overflow:hidden
#                 }
#                 .svg_container_1715150788 SVG {
#                     height:auto
#                 }
#             </style>
#             <script src="https://section5.ch/svg-pan-zoom.min.js"></script>
#             <script type="text/javascript">
#                 attempts = 5;
#                 var existCondition = setInterval(function() {
#                   console.log(attempts);
#                   svg_el = document.querySelector(".svg_container_1715150788 svg");
#                   if (svg_el != null) {
#                       console.log("Exists!");
#                       clearInterval(existCondition);
#                       svgPanZoom(svg_el, {controlIconsEnabled: true, zoomScaleSensitivity: 0.4, minZoom: 0.2});
#                   }
#                   if (--attempts == 0) {
#                       console.warn("SVG element not found, zoom wont work");
#                       clearInterval(existCondition);
#                   }
#                 }, 100); // check every 100ms
#             </script>
#             <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="897pt" height="217pt" viewBox="0.00 0.00 896.60 217.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 213)">
# <title>unit</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-213 892.6,-213 892.6,4 -4,4"/>
# <text text-anchor="middle" x="444.3" y="-7.8" font-family="Times,serif" font-size="14.00">unit</text>
# <!-- n7 -->
# <g id="node1" class="node">
# <title>n7</title>
# <polygon fill="none" stroke="black" points="888.6,-106.54 888.6,-121.46 872.78,-132 850.42,-132 834.6,-121.46 834.6,-106.54 850.42,-96 872.78,-96 888.6,-106.54"/>
# <text text-anchor="middle" x="861.6" y="-110.3" font-family="Times,serif" font-size="14.00">q</text>
# </g>
# <!-- n8 -->
# <g id="node2" class="node">
# <title>n8</title>
# <polygon fill="none" stroke="black" points="54,-66.54 54,-81.46 38.18,-92 15.82,-92 0,-81.46 0,-66.54 15.82,-56 38.18,-56 54,-66.54"/>
# <text text-anchor="middle" x="27" y="-70.3" font-family="Times,serif" font-size="14.00">b</text>
# </g>
# <!-- c21 -->
# <g id="node8" class="node">
# <title>c21</title>
# <polygon fill="none" stroke="black" points="95.5,-46 95.5,-92 328.5,-92 328.5,-46 95.5,-46"/>
# <text text-anchor="middle" x="109" y="-76.8" font-family="Times,serif" font-size="14.00">A</text>
# <polyline fill="none" stroke="black" points="95.5,-69 122.5,-69 "/>
# <text text-anchor="middle" x="109" y="-53.8" font-family="Times,serif" font-size="14.00">B</text>
# <polyline fill="none" stroke="black" points="122.5,-46 122.5,-92 "/>
# <text text-anchor="middle" x="212.5" y="-72.8" font-family="Times,serif" font-size="14.00">$worker:13::c17c/or:_u</text>
# <text text-anchor="middle" x="212.5" y="-57.8" font-family="Times,serif" font-size="14.00">$or</text>
# <polyline fill="none" stroke="black" points="302.5,-46 302.5,-92 "/>
# <text text-anchor="middle" x="315.5" y="-65.3" font-family="Times,serif" font-size="14.00">Y</text>
# </g>
# <!-- n8&#45;&gt;c21 -->
# <g id="edge10" class="edge">
# <title>n8:e-&gt;c21:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M54,-74C69.39,-74 73.39,-63.2 84.15,-58.82"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="84.8,-62.26 94,-57 83.53,-55.37 84.8,-62.26"/>
# </g>
# <!-- c22 -->
# <g id="node9" class="node">
# <title>c22</title>
# <polygon fill="none" stroke="black" points="90,-111 90,-157 334,-157 334,-111 90,-111"/>
# <text text-anchor="middle" x="103.5" y="-141.8" font-family="Times,serif" font-size="14.00">A</text>
# <polyline fill="none" stroke="black" points="90,-134 117,-134 "/>
# <text text-anchor="middle" x="103.5" y="-118.8" font-family="Times,serif" font-size="14.00">B</text>
# <polyline fill="none" stroke="black" points="117,-111 117,-157 "/>
# <text text-anchor="middle" x="212.5" y="-137.8" font-family="Times,serif" font-size="14.00">$worker:15::8133/xor:_u</text>
# <text text-anchor="middle" x="212.5" y="-122.8" font-family="Times,serif" font-size="14.00">$xor</text>
# <polyline fill="none" stroke="black" points="308,-111 308,-157 "/>
# <text text-anchor="middle" x="321" y="-130.3" font-family="Times,serif" font-size="14.00">Y</text>
# </g>
# <!-- n8&#45;&gt;c22 -->
# <g id="edge11" class="edge">
# <title>n8:e-&gt;c22:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M54,-74C76.5,-74 67.68,-108.17 80.39,-118.85"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="79.41,-122.21 90,-122 81.59,-115.56 79.41,-122.21"/>
# </g>
# <!-- n9 -->
# <g id="node3" class="node">
# <title>n9</title>
# <polygon fill="none" stroke="black" points="54,-129.54 54,-144.46 38.18,-155 15.82,-155 0,-144.46 0,-129.54 15.82,-119 38.18,-119 54,-129.54"/>
# <text text-anchor="middle" x="27" y="-133.3" font-family="Times,serif" font-size="14.00">a</text>
# </g>
# <!-- n9&#45;&gt;c21 -->
# <g id="edge12" class="edge">
# <title>n9:e-&gt;c21:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M54,-137C80.52,-137 68.12,-94.89 84.31,-83.7"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="85.31,-87.06 94,-81 83.43,-80.31 85.31,-87.06"/>
# </g>
# <!-- n9&#45;&gt;c22 -->
# <g id="edge13" class="edge">
# <title>n9:e-&gt;c22:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M54,-137C66.5,-137 71.26,-142.17 80.01,-144.67"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="79.63,-148.15 90,-146 80.55,-141.21 79.63,-148.15"/>
# </g>
# <!-- n10 -->
# <g id="node4" class="node">
# <title>n10</title>
# <polygon fill="none" stroke="black" points="424,-33.54 424,-48.46 408.18,-59 385.82,-59 370,-48.46 370,-33.54 385.82,-23 408.18,-23 424,-33.54"/>
# <text text-anchor="middle" x="397" y="-37.3" font-family="Times,serif" font-size="14.00">en</text>
# </g>
# <!-- c20 -->
# <g id="node7" class="node">
# <title>c20</title>
# <polygon fill="none" stroke="black" points="460,-44.5 460,-113.5 586,-113.5 586,-44.5 460,-44.5"/>
# <text text-anchor="middle" x="473.5" y="-98.3" font-family="Times,serif" font-size="14.00">A</text>
# <polyline fill="none" stroke="black" points="460,-90.5 487,-90.5 "/>
# <text text-anchor="middle" x="473.5" y="-75.3" font-family="Times,serif" font-size="14.00">B</text>
# <polyline fill="none" stroke="black" points="460,-67.5 487,-67.5 "/>
# <text text-anchor="middle" x="473.5" y="-52.3" font-family="Times,serif" font-size="14.00">S</text>
# <polyline fill="none" stroke="black" points="487,-44.5 487,-113.5 "/>
# <text text-anchor="middle" x="523.5" y="-82.8" font-family="Times,serif" font-size="14.00">$Mux_0</text>
# <text text-anchor="middle" x="523.5" y="-67.8" font-family="Times,serif" font-size="14.00">$mux</text>
# <polyline fill="none" stroke="black" points="560,-44.5 560,-113.5 "/>
# <text text-anchor="middle" x="573" y="-75.3" font-family="Times,serif" font-size="14.00">Y</text>
# </g>
# <!-- n10&#45;&gt;c20 -->
# <g id="edge2" class="edge">
# <title>n10:e-&gt;c20:w</title>
# <path fill="none" stroke="black" d="M424,-41C437.27,-41 441.16,-49.79 450.04,-53.91"/>
# <polygon fill="black" stroke="black" points="449.49,-57.38 460,-56 450.93,-50.53 449.49,-57.38"/>
# </g>
# <!-- n11 -->
# <g id="node5" class="node">
# <title>n11</title>
# <polygon fill="none" stroke="black" points="550,-142.54 550,-157.46 534.18,-168 511.82,-168 496,-157.46 496,-142.54 511.82,-132 534.18,-132 550,-142.54"/>
# <text text-anchor="middle" x="523" y="-146.3" font-family="Times,serif" font-size="14.00">clk</text>
# </g>
# <!-- c15 -->
# <g id="node6" class="node">
# <title>c15</title>
# <polygon fill="none" stroke="black" points="622,-91 622,-137 759,-137 759,-91 622,-91"/>
# <text text-anchor="middle" x="645.5" y="-121.8" font-family="Times,serif" font-size="14.00">CLK</text>
# <polyline fill="none" stroke="black" points="622,-114 669,-114 "/>
# <text text-anchor="middle" x="645.5" y="-98.8" font-family="Times,serif" font-size="14.00">D</text>
# <polyline fill="none" stroke="black" points="669,-91 669,-137 "/>
# <text text-anchor="middle" x="700" y="-117.8" font-family="

# %% [markdown]
# ### Conclusion
#
# We can verify the logic being created for this unit as follows:
# The `en` if..else construct creates a multiplexer primitive, selecting from the two prepended logic gates. More selection scenarios would create cascaded mulitplexers (this is left as an example).
#
# Finally, the output value is fed into a data flip flop `$dff`.
#
# The octagon pads represent the interface of the unit function. Our top level signals are not visible.

# %% [markdown]
# ## Hierarchical design display
#
# The `.display_rtl()` method can not deal with multi page output, i.e. only a module at a time ca be displayed. A hierarchical design requires to pass a `selection` parameter.
#
# First, a top level module is created with internal signals connected to `unit` instances

# %%
@block
def top():
    N = 12

    clk = ClkSignal()
    u0, v0, w0, = [ Signal(intbv()[N:]) for _ in range(3) ]
    u1, v1, w1, = [ Signal(intbv()[N-2:]) for _ in range(3) ]
    en = Signal(bool())

    inst0 = unit(clk, en, u0, v0, w0)
    inst1 = unit(clk, en, u1, v1, w1)

    return instances()

# %%
t = top()
objs = t.elab(rtl)
d = objs[0]
d.display_rtl(selection = top, inline = True)
# Out:
#  Module top: Existing instance unit, rename to unit_1
#  Module top: Existing instance unit, rename to unit_2
#  Adding module with name `unit_2`
#  Adding module with name `unit_1`
#  Adding module with name `top`
#  FINALIZE implementation `top` of `top`
#         <div class="svg_container_1715150789">
#             <style>
#                 .svg_container_1715150789 {
#                     overflow:hidden
#                 }
#                 .svg_container_1715150789 SVG {
#                     height:auto
#                 }
#             </style>
#             <script src="https://section5.ch/svg-pan-zoom.min.js"></script>
#             <script type="text/javascript">
#                 attempts = 5;
#                 var existCondition = setInterval(function() {
#                   console.log(attempts);
#                   svg_el = document.querySelector(".svg_container_1715150789 svg");
#                   if (svg_el != null) {
#                       console.log("Exists!");
#                       clearInterval(existCondition);
#                       svgPanZoom(svg_el, {controlIconsEnabled: true, zoomScaleSensitivity: 0.4, minZoom: 0.2});
#                   }
#                   if (--attempts == 0) {
#                       console.warn("SVG element not found, zoom wont work");
#                       clearInterval(existCondition);
#                   }
#                 }, 100); // check every 100ms
#             </script>
#             <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="412pt" height="391pt" viewBox="0.00 0.00 411.73 391.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 387)">
# <title>top</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-387 407.73,-387 407.73,4 -4,4"/>
# <text text-anchor="middle" x="201.86" y="-7.8" font-family="Times,serif" font-size="14.00">top</text>
# <!-- n1 -->
# <g id="node1" class="node">
# <title>n1</title>
# <polygon fill="none" stroke="black" points="68.94,-275 37.93,-257 68.94,-239 99.94,-257 68.94,-275"/>
# <text text-anchor="middle" x="68.94" y="-253.3" font-family="Times,serif" font-size="14.00">v1</text>
# </g>
# <!-- c13 -->
# <g id="node9" class="node">
# <title>c13</title>
# <polygon fill="none" stroke="black" points="173.87,-179 173.87,-271 297.87,-271 297.87,-179 173.87,-179"/>
# <text text-anchor="middle" x="192.37" y="-255.8" font-family="Times,serif" font-size="14.00">a</text>
# <polyline fill="none" stroke="black" points="173.87,-248 210.87,-248 "/>
# <text text-anchor="middle" x="192.37" y="-232.8" font-family="Times,serif" font-size="14.00">b</text>
# <polyline fill="none" stroke="black" points="173.87,-225 210.87,-225 "/>
# <text text-anchor="middle" x="192.37" y="-209.8" font-family="Times,serif" font-size="14.00">clk</text>
# <polyline fill="none" stroke="black" points="173.87,-202 210.87,-202 "/>
# <text text-anchor="middle" x="192.37" y="-186.8" font-family="Times,serif" font-size="14.00">en</text>
# <polyline fill="none" stroke="black" points="210.87,-179 210.87,-271 "/>
# <text text-anchor="middle" x="241.37" y="-228.8" font-family="Times,serif" font-size="14.00">unit_1</text>
# <text text-anchor="middle" x="241.37" y="-213.8" font-family="Times,serif" font-size="14.00">unit_2</text>
# <polyline fill="none" stroke="black" points="271.87,-179 271.87,-271 "/>
# <text text-anchor="middle" x="284.87" y="-221.3" font-family="Times,serif" font-size="14.00">q</text>
# </g>
# <!-- n1&#45;&gt;c13 -->
# <g id="edge1" class="edge">
# <title>n1:e-&gt;c13:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M100.94,-257C130.87,-257 138.68,-241.14 163.77,-237.67"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="164.13,-241.15 173.87,-237 163.67,-234.17 164.13,-241.15"/>
# </g>
# <!-- n2 -->
# <g id="node2" class="node">
# <title>n2</title>
# <polygon fill="none" stroke="black" points="68.94,-329 36.59,-311 68.94,-293 101.28,-311 68.94,-329"/>
# <text text-anchor="middle" x="68.94" y="-307.3" font-family="Times,serif" font-size="14.00">u1</text>
# </g>
# <!-- n2&#45;&gt;c13 -->
# <g id="edge2" class="edge">
# <title>n2:e-&gt;c13:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M101.94,-311C137.3,-311 135.51,-269.47 163.61,-261.36"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="164.42,-264.79 173.87,-260 163.5,-257.85 164.42,-264.79"/>
# </g>
# <!-- n3 -->
# <g id="node3" class="node">
# <title>n3</title>
# <polygon fill="none" stroke="black" points="368.8,-243 333.95,-225 368.8,-207 403.66,-225 368.8,-243"/>
# <text text-anchor="middle" x="368.8" y="-221.3" font-family="Times,serif" font-size="14.00">w1</text>
# </g>
# <!-- n4 -->
# <g id="node4" class="node">
# <title>n4</title>
# <polygon fill="none" stroke="black" points="68.94,-113 37.93,-95 68.94,-77 99.94,-95 68.94,-113"/>
# <text text-anchor="middle" x="68.94" y="-91.3" font-family="Times,serif" font-size="14.00">v0</text>
# </g>
# <!-- c14 -->
# <g id="node10" class="node">
# <title>c14</title>
# <polygon fill="none" stroke="black" points="173.87,-58 173.87,-150 297.87,-150 297.87,-58 173.87,-58"/>
# <text text-anchor="middle" x="192.37" y="-134.8" font-family="Times,serif" font-size="14.00">a</text>
# <polyline fill="none" stroke="black" points="173.87,-127 210.87,-127 "/>
# <text text-anchor="middle" x="192.37" y="-111.8" font-family="Times,serif" font-size="14.00">b</text>
# <polyline fill="none" stroke="black" points="173.87,-104 210.87,-104 "/>
# <text text-anchor="middle" x="192.37" y="-88.8" font-family="Times,serif" font-size="14.00">clk</text>
# <polyline fill="none" stroke="black" points="173.87,-81 210.87,-81 "/>
# <text text-anchor="middle" x="192.37" y="-65.8" font-family="Times,serif" font-size="14.00">en</text>
# <polyline fill="none" stroke="black" points="210.87,-58 210.87,-150 "/>
# <text text-anchor="middle" x="241.37" y="-107.8" font-family="Times,serif" font-size="14.00">unit_0</text>
# <text text-anchor="middle" x="241.37" y="-92.8" font-family="Times,serif" font-size="14.00">unit_1</text>
# <polyline fill="none" stroke="black" points="271.87,-58 271.87,-150 "/>
# <text text-anchor="middle" x="284.87" y="-100.3" font-family="Times,serif" font-size="14.00">q</text>
# </g>
# <!-- n4&#45;&gt;c14 -->
# <g id="edge4" class="edge">
# <title>n4:e-&gt;c14:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M100.94,-95C130.98,-95 138.61,-111.66 163.75,-115.3"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="163.66,-118.8 173.87,-116 164.14,-111.82 163.66,-118.8"/>
# </g>
# <!-- n5 -->
# <g id="node5" class="node">
# <title>n5</title>
# <polygon fill="none" stroke="black" points="68.94,-167 36.59,-149 68.94,-131 101.28,-149 68.94,-167"/>
# <text text-anchor="middle" x="68.94" y="-145.3" font-family="Times,serif" font-size="14.00">u0</text>
# </g>
# <!-- n5&#45;&gt;c14 -->
# <g id="edge5" class="edge">
# <title>n5:e-&gt;c14:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M101.94,-149C130.56,-149 139.6,-141.14 163.79,-139.36"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="164,-142.85 173.87,-139 163.76,-135.86 164,-142.85"/>
# </g>
# <!-- n6 -->
# <g id="node6" class="node">
# <title>n6</title>
# <polygon fill="none" stroke="black" points="68.94,-59 37.93,-41 68.94,-23 99.94,-41 68.94,-59"/>
# <text text-anchor="middle" x="68.94" y="-37.3" font-family="Times,serif" font-size="14.00">en</text>
# </g>
# <!-- n6&#45;&gt;c13 -->
# <g id="edge6" class="edge">
# <title>n6:e-&gt;c13:w</title>
# <path fill="none" stroke="black" d="M100.94,-41C121.27,-41 126.17,-51.37 137.87,-68 168.12,-110.98 124.38,-179.49 163.51,-188.91"/>
# <polygon fill="black" stroke="black" points="163.56,-192.44 173.87,-190 164.29,-185.48 163.56,-192.44"/>
# </g>
# <!-- n6&#45;&gt;c14 -->
# <g id="edge7" class="edge">
# <title>n6:e-&gt;c14:w</title>
# <path fill="none" stroke="black" d="M100.94,-41C132,-41 138.07,-63.41 163.86,-68.13"/>
# <polygon fill="black" stroke="black" points="163.61,-71.62 173.87,-69 164.21,-64.65 163.61,-71.62"/>
# </g>
# <!-- n7 -->
# <g id="node7" class="node">
# <title>n7</title>
# <polygon fill="none" stroke="black" points="68.94,-221 0.06,-203 68.94,-185 137.81,-203 68.94,-221"/>
# <text text-anchor="middle" x="68.94" y="-199.3" font-family="Times,serif" font-size="14.00">clk_e6f4</text>
# </g>
# <!-- n7&#45;&gt;c13 -->
# <g id="edge8" class="edge">
# <title>n7:e-&gt;c13:w</title>
# <path fill="none" stroke="black" d="M137.87,-203C150.46,-203

# %% [markdown]
# We observe the internal signals being represented by wedges, whereas the unit instances are shown as black box modules..

# %% [markdown]
# # Synthesis for target
#
# To synthesize for a specific target, a `@cyrite_factory.Module` class is first created. Then, it is instanced by passing an `Architecture` class, containing the configuration for the FPGA target and associated toolchain.
#
# See also [Design](methods.ipynb).
#
# The `@cyrite_factory.Module` object represents the top level design in various configurations. Typically, a user would supply a `.build()` method that calls the entire flow process with the result of a binary file ready to download to the target.
#
# However since this is very system specific, the ways to do are intentially left open and can be freely implemented by the user.

# %% [markdown]
# ## Customizing RTLIL targets
#
# When the `.elab()` method is called, the design is elaborated as RTLIL and a list of design elements is returned, the first being a RTLIL Design handle.
# The `.finalize()` method is called last inside elaboration, which can perform some optimizations or emissions to specific targets.

# %%
from myirl.targets import pyosys

class MyRTL(pyosys.RTLIL):
    def finalize(self, top, objs = None):
        tname = top.name
        design = self._design
        design.run("hierarchy -top %s" % tname)
        print(80 * '=')
        design.write_verilog(name = top.obj.name)
        design.run("flatten; ls; select %s; stat" % tname)
        
        return [design]

# %% [markdown]
# The `.finalize()` function must return the created elements in a list, which is in turn returned from the `.elab()` call.

# %%
rtl = MyRTL("top")
t = top()
objs = t.elab(rtl)
d = objs[0]
d.display_rtl(selection = top, inline = True)
# Out:
#  Module top: Existing instance top, rename to top_1
#  Module top: Existing instance unit, rename to unit_3
#  Module top: Existing instance unit, rename to unit_4
#  Adding module with name `unit_4`
#  Adding module with name `unit_3`
#  Adding module with name `top_1`
# ================================================================================
# Warning: Several variants of unit `[wrapped_wrapper 'top/top']`. Picking first.
#         <div class="svg_container_1715150790">
#             <style>
#                 .svg_container_1715150790 {
#                     overflow:hidden
#                 }
#                 .svg_container_1715150790 SVG {
#                     height:auto
#                 }
#             </style>
#             <script src="https://section5.ch/svg-pan-zoom.min.js"></script>
#             <script type="text/javascript">
#                 attempts = 5;
#                 var existCondition = setInterval(function() {
#                   console.log(attempts);
#                   svg_el = document.querySelector(".svg_container_1715150790 svg");
#                   if (svg_el != null) {
#                       console.log("Exists!");
#                       clearInterval(existCondition);
#                       svgPanZoom(svg_el, {controlIconsEnabled: true, zoomScaleSensitivity: 0.4, minZoom: 0.2});
#                   }
#                   if (--attempts == 0) {
#                       console.warn("SVG element not found, zoom wont work");
#                       clearInterval(existCondition);
#                   }
#                 }, 100); // check every 100ms
#             </script>
#             <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="1547pt" height="548pt" viewBox="0.00 0.00 1547.40 547.50">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 543.5)">
# <title>top_1</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-543.5 1543.4,-543.5 1543.4,4 -4,4"/>
# <text text-anchor="middle" x="769.7" y="-7.8" font-family="Times,serif" font-size="14.00">top_1</text>
# <!-- n1 -->
# <g id="node1" class="node">
# <title>n1</title>
# <polygon fill="none" stroke="black" points="1325.93,-233.5 1257.89,-215.5 1325.93,-197.5 1393.96,-215.5 1325.93,-233.5"/>
# <text text-anchor="middle" x="1325.93" y="-211.8" font-family="Times,serif" font-size="14.00">unit_0.q</text>
# </g>
# <!-- x15 -->
# <g id="node44" class="node">
# <title>x15</title>
# <ellipse fill="black" stroke="black" cx="1431.75" cy="-215.5" rx="1.8" ry="1.8"/>
# </g>
# <!-- n1&#45;&gt;x15 -->
# <g id="edge2" class="edge">
# <title>n1:e-&gt;x15:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M1393.95,-215.5C1405.95,-215.5 1411.2,-215.5 1419.82,-215.5"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="1419.95,-219 1429.95,-215.5 1419.95,-212 1419.95,-219"/>
# </g>
# <!-- n2 -->
# <g id="node2" class="node">
# <title>n2</title>
# <polygon fill="none" stroke="black" points="738.93,-264.5 662.84,-246.5 738.93,-228.5 815.01,-246.5 738.93,-264.5"/>
# <text text-anchor="middle" x="738.93" y="-242.8" font-family="Times,serif" font-size="14.00">unit_0.en</text>
# </g>
# <!-- c37 -->
# <g id="node21" class="node">
# <title>c37</title>
# <polygon fill="none" stroke="black" points="867.26,-250 867.26,-319 993.26,-319 993.26,-250 867.26,-250"/>
# <text text-anchor="middle" x="880.76" y="-303.8" font-family="Times,serif" font-size="14.00">A</text>
# <polyline fill="none" stroke="black" points="867.26,-296 894.26,-296 "/>
# <text text-anchor="middle" x="880.76" y="-280.8" font-family="Times,serif" font-size="14.00">B</text>
# <polyline fill="none" stroke="black" points="867.26,-273 894.26,-273 "/>
# <text text-anchor="middle" x="880.76" y="-257.8" font-family="Times,serif" font-size="14.00">S</text>
# <polyline fill="none" stroke="black" points="894.26,-250 894.26,-319 "/>
# <text text-anchor="middle" x="930.76" y="-288.3" font-family="Times,serif" font-size="14.00">$Mux_4</text>
# <text text-anchor="middle" x="930.76" y="-273.3" font-family="Times,serif" font-size="14.00">$mux</text>
# <polyline fill="none" stroke="black" points="967.26,-250 967.26,-319 "/>
# <text text-anchor="middle" x="980.26" y="-280.8" font-family="Times,serif" font-size="14.00">Y</text>
# </g>
# <!-- n2&#45;&gt;c37 -->
# <g id="edge21" class="edge">
# <title>n2:e-&gt;c37:w</title>
# <path fill="none" stroke="black" d="M815.22,-246.5C834.98,-246.5 840.85,-256.98 856.05,-260.42"/>
# <polygon fill="black" stroke="black" points="855.95,-263.93 866.26,-261.5 856.69,-256.97 855.95,-263.93"/>
# </g>
# <!-- n3 -->
# <g id="node3" class="node">
# <title>n3</title>
# <polygon fill="none" stroke="black" points="930.26,-231.5 851.17,-213.5 930.26,-195.5 1009.36,-213.5 930.26,-231.5"/>
# <text text-anchor="middle" x="930.26" y="-209.8" font-family="Times,serif" font-size="14.00">unit_0.clk</text>
# </g>
# <!-- c41 -->
# <g id="node22" class="node">
# <title>c41</title>
# <polygon fill="none" stroke="black" points="1045.31,-192.5 1045.31,-238.5 1182.31,-238.5 1182.31,-192.5 1045.31,-192.5"/>
# <text text-anchor="middle" x="1068.81" y="-223.3" font-family="Times,serif" font-size="14.00">CLK</text>
# <polyline fill="none" stroke="black" points="1045.31,-215.5 1092.31,-215.5 "/>
# <text text-anchor="middle" x="1068.81" y="-200.3" font-family="Times,serif" font-size="14.00">D</text>
# <polyline fill="none" stroke="black" points="1092.31,-192.5 1092.31,-238.5 "/>
# <text text-anchor="middle" x="1123.31" y="-219.3" font-family="Times,serif" font-size="14.00">$Dff_4</text>
# <text text-anchor="middle" x="1123.31" y="-204.3" font-family="Times,serif" font-size="14.00">$dff</text>
# <polyline fill="none" stroke="black" points="1154.31,-192.5 1154.31,-238.5 "/>
# <text text-anchor="middle" x="1168.31" y="-211.8" font-family="Times,serif" font-size="14.00">Q</text>
# </g>
# <!-- n3&#45;&gt;c41 -->
# <g id="edge35" class="edge">
# <title>n3:e-&gt;c41:w</title>
# <path fill="none" stroke="black" d="M1009.31,-213.5C1022.45,-213.5 1026.51,-221.71 1035.4,-225.55"/>
# <polygon fill="black" stroke="black" points="1034.82,-229.01 1045.31,-227.5 1036.17,-222.14 1034.82,-229.01"/>
# </g>
# <!-- n4 -->
# <g id="node4" class="node">
# <title>n4</title>
# <polygon fill="none" stroke="black" points="278.62,-299.5 210.58,-281.5 278.62,-263.5 346.65,-281.5 278.62,-299.5"/>
# <text text-anchor="middle" x="278.62" y="-277.8" font-family="Times,serif" font-size="14.00">unit_0.b</text>
# </g>
# <!-- c35 -->
# <g id="node20" class="node">
# <title>c35</title>
# <polygon fill="none" stroke="black" points="387.14,-261.5 387.14,-307.5 622.14,-307.5 622.14,-261.5 387.14,-261.5"/>
# <text text-anchor="middle" x="400.64" y="-292.3" font-family="Times,serif" font-size="14.00">A</text>
# <polyline fill="none" stroke="black" points="387.14,-284.5 414.14,-284.5 "/>
# <text text-anchor="middle" x="400.64" y="-269.3" font-family="Times,serif" font-size="14.00">B</text>
# <polyline fill="none" stroke="black" points="414.14,-261.5 414.14,-307.5 "/>
# <text text-anchor="middle" x="505.14" y="-288.3" font-family="Times,serif" font-size="14.00">$worker:13::e074/or:_u</text>
# <text text-anchor="middle" x="505.14" y="-273.3" font-family="Times,serif" font-size="14.00">$or</text>
# <polyline fill="none" stroke="black" points="596.14,-261.5 596.14,-307.5 "/>
# <text text-anchor="middle" x="609.14" y="-280.8" font-family="Times,serif" font-size="14.00">Y</text>
# </g>
# <!-- n4&#45;&gt;c35 -->
# <g id="edge38" class="edge">
# <title>n4:e-&gt;c35:w</title>
# <path fill="none" stroke="black" stroke-width="3" d="M346.64,-281.5C360.39,-281.5 365.56,-276.12 375.42,-273.68"/>
# <polygon fill="black" stroke="black" stroke-width="3" points="376.1,-277.12 385.64,-272.5 375.3,-270.17 376.1,-277.12"/>
# </g>
# <!-- c46 -->
# <g id="node27" class="node">
# <title>c46</title>
# <polygon fill="none" stroke="black" points="384.64,-326.5 384.64,-372.5 624.64,-372.5 624.64,-326.5 384.64,-326.5"/>
# <text text-anchor="middle" x="398.14" y="-357.3" font-family="Times,serif" font-size="14.00">A</text>
# <polyline fill="none" stroke="black" points="384.64,-349.5 411.64,-349.5 "/>
# <text text-anchor="middle" x="398.14" y="-334.3" font-family="Times,serif" font-size="14.00">B</text>
# <polyline fill="none" stroke="black" points="411.64,-326.5 411.64,-372.5 "/>
# <text text-anchor="middle" x="505.14" y="-353.3" font-family="Times,serif" font-size="14.00">$worker:15::16fe/xor:_u</text>
# <text text-anchor="middle" x="505.14" y="-338.3" font-family="Times,serif" font-size="14.00">$xor</text>
# <polyline fill="none" stroke="black" points="598.64,-326.5 598.64,-372.5 "/>
# <text t
